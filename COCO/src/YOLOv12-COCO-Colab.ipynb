# %% [markdown]
# # YOLOv12: Attention-Centric Real-Time Object Detectors
# Since the dataset is large, we reproduced the model result using Google Colab.

# %% [markdown]
# ## Environment setup

# %%
import os
from google.colab import userdata

os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")

# %% [markdown]
# ### Check GPU availability

# %%
# !nvidia-smi
# Out:
# Thu Apr 10 22:05:12 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ### Install dependencies
#
# **NOTE:** Currently, YOLOv12 does not have its own PyPI package, so we install it directly from GitHub.

# %%
# !pip install -q git+https://github.com/sunsmarterjie/yolov12.git roboflow supervision flash-attn
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 68.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 80.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Evaluate YOLOv12 model using COCO

# %% [markdown]
# ### YOLOv12n

# %%
from ultralytics import YOLO

model = YOLO('yolov12n.pt')
model.val(data='coco.yaml', save_json=True)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/yolov12/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# FlashAttention is not available on this device. Using scaled_dot_product_attention instead.
# ...
# 100%|██████████| 5.26M/5.26M [00:00<00:00, 106MB/s]
# Ultralytics 8.3.63 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12n summary (fused): 376 layers, 2,542,440 parameters, 0 gradients, 6.0 GFLOPs
#
# Dataset 'coco.yaml' images not found ⚠️, missing path '/content/datasets/..datasets/coco/val2017.txt'
# ...
# 100%|██████████| 169M/169M [00:01<00:00, 104MB/s]
# Unzipping /content/datasets/..datasets/coco2017labels-segments.zip to /content/datasets/..datasets/coco...: 100%|██████████| 122232/122232 [00:20<00:00, 6018.20file/s]
# ...

# %% [markdown]
# ### YOLOv12s

# %%
from ultralytics import YOLO

model = YOLO('yolov12s.pt')
model.val(data='coco.yaml', save_json=True)
# Out:
# ...
# 100%|██████████| 17.8M/17.8M [00:00<00:00, 59.0MB/s]
# Ultralytics 8.3.63 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12s summary (fused): 376 layers, 9,105,168 parameters, 0 gradients, 19.4 GFLOPs
# val: Scanning /content/datasets/..datasets/coco/labels/val2017.cache... 4952 images, 48 backgrounds, 0 corrupt: 100%|██████████| 5000/5000 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 313/313 [01:47<00:00,  2.91it/s]
#                    all       5000      36335      0.715      0.583      0.641      0.476
#                 person       2693      10777       0.82      0.719      0.811       0.59
#                bicycle        149        314      0.731       0.49      0.591      0.368
#                    car        535       1918       0.74      0.584      0.673      0.457
#             motorcycle        159        367      0.791      0.703      0.768      0.508
# ...

# %% [markdown]
# ### YOLOv12m

# %%
from ultralytics import YOLO

model = YOLO('yolov12m.pt')
model.val(data='coco.yaml', save_json=True)
# Out:
# ...
# 100%|██████████| 38.0M/38.0M [00:00<00:00, 82.1MB/s]
# Ultralytics 8.3.63 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12m summary (fused): 402 layers, 19,638,208 parameters, 0 gradients, 59.8 GFLOPs
# val: Scanning /content/datasets/..datasets/coco/labels/val2017.cache... 4952 images, 48 backgrounds, 0 corrupt: 100%|██████████| 5000/5000 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 313/313 [02:21<00:00,  2.21it/s]
#                    all       5000      36335      0.728      0.639      0.695      0.526
#                 person       2693      10777      0.823      0.762      0.844      0.632
#                bicycle        149        314      0.698      0.567      0.657       0.41
#                    car        535       1918      0.755       0.67      0.741      0.521
#             motorcycle        159        367      0.807      0.725      0.803      0.566
# ...

# %% [markdown]
# ### YOLOv12l

# %%
from ultralytics import YOLO

model = YOLO('yolov12l.pt')
model.val(data='coco.yaml', save_json=True)
# Out:
# ...
# 100%|██████████| 51.4M/51.4M [00:00<00:00, 95.4MB/s]
# Ultralytics 8.3.63 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12l summary (fused): 674 layers, 26,455,232 parameters, 0 gradients, 82.4 GFLOPs
# val: Scanning /content/datasets/..datasets/coco/labels/val2017.cache... 4952 images, 48 backgrounds, 0 corrupt: 100%|██████████| 5000/5000 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 313/313 [03:20<00:00,  1.56it/s]
#                    all       5000      36335      0.741      0.651      0.706       0.54
#                 person       2693      10777      0.832      0.761      0.848      0.642
#                bicycle        149        314      0.769      0.592      0.689      0.448
#                    car        535       1918       0.78      0.669      0.754      0.537
#             motorcycle        159        367       0.79      0.747      0.814       0.58
# ...

# %% [markdown]
# ### YOLOv12x

# %%
from ultralytics import YOLO

model = YOLO('yolov12x.pt')
model.val(data='coco.yaml', save_json=True)
# Out:
# ...
# 100%|██████████| 114M/114M [00:01<00:00, 87.1MB/s]
# Ultralytics 8.3.63 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12x summary (fused): 674 layers, 59,337,280 parameters, 0 gradients, 184.6 GFLOPs
# val: Scanning /content/datasets/..datasets/coco/labels/val2017.cache... 4952 images, 48 backgrounds, 0 corrupt: 100%|██████████| 5000/5000 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 313/313 [05:54<00:00,  1.13s/it]
#                    all       5000      36335      0.752      0.657      0.722      0.557
#                 person       2693      10777      0.841      0.758      0.854      0.654
#                bicycle        149        314      0.771      0.631       0.69      0.446
#                    car        535       1918      0.785      0.676      0.762      0.548
#             motorcycle        159        367      0.813      0.755      0.827      0.589
# ...
